# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudh007-tech/python-codes/blob/main/python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
print(a+b)
# Out:
# 30
